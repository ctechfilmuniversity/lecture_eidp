// %% [markdown]
// ### Einfühfung in die Programmierung - WS18/19 - Lena Gieseke
//
//
//
// ### Exercise 03 - Solutions
//
// -----------------------------------

// %% [markdown]
// ### Task 03.01

// %% [markdown]
// Take the code example 03.09 from the lecture as basis. Replace the mouse following of the circle with moving the circle with the arrow keys of the keyboard (up, down, left, right).
//
// Use Processing's keyCode and read the reference on how to use it.
//
// Hint
// - The controll and adjustment of the position variables happens now in the keyPressed() function.

// %%
float positionX = 0;
float positionY = 0;

float speed;

int hue = 0;

void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    speed = 5;
}


void draw()
{
    
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 10, 10);
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            positionY -= speed;
        } 
        else if (keyCode == DOWN) 
        {
            positionY += speed;
        }
        else if (keyCode == LEFT) 
        {
            positionX -= speed;
        } 
        else if (keyCode == RIGHT) 
        {
            positionX += speed;
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
// Out:
// <div id="canvas_div_3">
//   <b>Sketch #3:</b><br/>
//   <canvas id="canvas_3"></canvas><br/>
// </div>
// <div id="controls_div_3">
//   <button id="run_button_3" onclick="startSketch('3');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_3" onclick="pauseSketch('3');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_3" onclick="setupSketch('3');">
//     setup()
//   </button>
//   <button id="draw_button_3" onclick="drawSketch('3');">
//     draw()
//   </button>
// </div>
// <b>Sketch #3 state:</b> <span id="state_3">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Task 03.02

// %% [markdown]
// Add to your code the functionality that the user can not move the circle outside of the sketch window. If a user tries to move outside of the window, the circle should just not move any further.

// %%
float positionX;
float positionY;

float speed;

int hue = 0;

int radius;

void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    speed = 5;
    
     positionX = width * 0.5;
     positionY = height * 0.5;
    radius = 40;
}


void draw()
{
    
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, radius, radius);
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP && positionY >= radius) 
        {
            positionY -= speed;
        } 
        else if (keyCode == DOWN && positionY <= height) 
        {
            positionY += speed;
        }
        else if (keyCode == LEFT && positionX >= 0) 
        {
            positionX -= speed;   
        } 
        else if (keyCode == RIGHT && positionX <= width) 
        {
             positionX += speed;  
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
// Out:
// <div id="canvas_div_5">
//   <b>Sketch #5:</b><br/>
//   <canvas id="canvas_5"></canvas><br/>
// </div>
// <div id="controls_div_5">
//   <button id="run_button_5" onclick="startSketch('5');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_5" onclick="pauseSketch('5');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_5" onclick="setupSketch('5');">
//     setup()
//   </button>
//   <button id="draw_button_5" onclick="drawSketch('5');">
//     draw()
//   </button>
// </div>
// <b>Sketch #5 state:</b> <span id="state_5">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Task 03.03

// %% [markdown]
// Adjust your program so that the collision with the sktech window boarders is checked with the outside of the circle, not its center. The inital start position of the circle should be in the center of the sktech window.

// %%
float positionX;
float positionY;

float speed;

int radius;

int hue = 0;

void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 40;
    speed = 5;
}


void draw()
{
    
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
// Out:
// <div id="canvas_div_6">
//   <b>Sketch #6:</b><br/>
//   <canvas id="canvas_6"></canvas><br/>
// </div>
// <div id="controls_div_6">
//   <button id="run_button_6" onclick="startSketch('6');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_6" onclick="pauseSketch('6');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_6" onclick="setupSketch('6');">
//     setup()
//   </button>
//   <button id="draw_button_6" onclick="drawSketch('6');">
//     draw()
//   </button>
// </div>
// <b>Sketch #6 state:</b> <span id="state_6">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...
