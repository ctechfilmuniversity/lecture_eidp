// %% [markdown]
// ### Einfühfung in die Programmierung - WS18/19 - Lena Gieseke
//
//
//
// ### Exercise 04 - Solutions
//
// -----------------------------------

// %% [markdown]
// ### Task 04.01  - Distribute Coins (3 Points)

// %% [markdown]
// Use your code from Exercise 03 or the solution as basis. On our way to creating a Pacman game, we now want to distribute coins an the canvas and be able to 'eat' them (meaning checking for a collision between the circle avatar and a coin).
//
// As first task create a (in an variable specified) number of coins, which are randomly distributed on the canvas. For now you can use any shape you like as coin, for example just a simple rectangle.
//
// Defining the variables and arrays
// * Create two global integer variables, one for the number of coins, one for the coin size.
// * Create two global float arrays, one for the x position of the coins, one for the y position. The arrays should have the number of coins as size.
//
// Storing values in  the variables and arrays
// * In the setup function create a loop with as many iterations as number of coins. In each iteration, assign each x and y array position a random number within the canvas (remember: width, height).
//
// Drawing the coins
// * In the draw function create a loop with as many iterations as number of coins. In each iteration draw a rectangle of coin size at the positions that are stored in the position arrays.

// %%
float positionX;
float positionY;

float speed;

int radius;

int hue = 0;

void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 40;
    speed = 5;
}


void draw()
{
    
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP && positionY >= radius) 
        {
            positionY -= speed;
        } 
        else if (keyCode == DOWN && positionY <= height - radius) 
        {
            positionY += speed;
        }
        else if (keyCode == LEFT && positionX >= radius) 
        {
            positionX -= speed;   
        } 
        else if (keyCode == RIGHT && positionX <= width - radius) 
        {
             positionX += speed;  
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}

// %% [markdown]
// Solution:

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 10;
float[] coinsPositionX = new float[coinsNum];
float[] coinsPositionY = new float[coinsNum];



void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    for(int i = 0; i < coinsNum; i++)
    {
        coinsPositionX[i] = random(coinsSize, width - coinsSize);
        coinsPositionY[i] = random(coinsSize, height - coinsSize);  
    }
}


void draw()
{
    background(0, 0, 100);
    
   
    // COINS
    for(int i = 0; i < coinsNum; i++)
    {
        fill(40, 100, 100);
        rect(coinsPositionX[i], coinsPositionY[i], coinsSize, coinsSize);
    }
    
    
    
    // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
    
    
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Task 04.02 - Collision With Coins (3 Points)
//
// Now we want to detect whether we moved the circle avatar above a coin, hence check for a collision between avatar and coin.
//
// * As we need to constantly check for a collision, this needs to happen inside the draw() function.
// * We need to check each coin in each draw() call and we can continue within the for loop we created for drawing the coins.
// * Add a if-condition inside the existing for-loop befor drawing the coin
//     * Now we want to check if the position of the avatar is inside the coin, which we are about to draw.
//     * Check if the x-position of the avatar is larger than the x-position of the coin AND smaller than the x-position of the coin plus the coin size AND do it accordingly for y.
//     * When the avatar is colliding with a coin, hence the if-condition becomes true, print something to the console to indicate that the coin is eaten.

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 10;
float[] coinsPositionX = new float[coinsNum];
float[] coinsPositionY = new float[coinsNum];



void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    for(int i = 0; i < coinsNum; i++)
    {
        coinsPositionX[i] = random(coinsSize, width - coinsSize);
        coinsPositionY[i] = random(coinsSize, height - coinsSize);  
    }
}


void draw()
{
    background(0, 0, 100);
    
   
    // COINS
    for(int i = 0; i < coinsNum; i++)
    {
        fill(40, 100, 100);
        rect(coinsPositionX[i], coinsPositionY[i], coinsSize, coinsSize);
    }
    
    
    
    // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
    
    
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}

// %% [markdown]
// Solution:

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 10;
float[] coinsPositionX = new float[coinsNum];
float[] coinsPositionY = new float[coinsNum];
boolean[] coinsActive = new boolean[coinsNum];


void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    for(int i = 0; i < coinsNum; i++)
    {
        coinsPositionX[i] = random(coinsSize, width - coinsSize);
        coinsPositionY[i] = random(coinsSize, height - coinsSize);  
    }
}


void draw()
{
    background(0, 0, 100);
    
   
    // COINS
    for(int i = 0; i < coinsNum; i++)
    {
        //Check for a collision of the avatar with a coin
        if(positionX >= coinsPositionX[i] && positionX <= coinsPositionX[i] + coinsSize &&
            positionY >= coinsPositionY[i] && positionY <= coinsPositionY[i] + coinsSize)
        {
            println("Yummy!");
        }
        
        fill(40, 100, 100);
        rect(coinsPositionX[i], coinsPositionY[i], coinsSize, coinsSize);
    }
    
    
    
    // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
    
    
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
// Out:
// <div id="canvas_div_3">
//   <b>Sketch #3:</b><br/>
//   <canvas id="canvas_3"></canvas><br/>
// </div>
// <div id="controls_div_3">
//   <button id="run_button_3" onclick="startSketch('3');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_3" onclick="pauseSketch('3');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_3" onclick="setupSketch('3');">
//     setup()
//   </button>
//   <button id="draw_button_3" onclick="drawSketch('3');">
//     draw()
//   </button>
// </div>
// <b>Sketch #3 state:</b> <span id="state_3">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// ### Bonus
//
// With an `active` property for the coins, saved in another array, we control the drawing of the coins. We only want to draw coins which weren't eaten yet.

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 10;
float[] coinsPositionX = new float[coinsNum];
float[] coinsPositionY = new float[coinsNum];
boolean[] coinsActive = new boolean[coinsNum];


void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 100);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    for(int i = 0; i < coinsNum; i++)
    {
        coinsPositionX[i] = random(coinsSize, width - coinsSize);
        coinsPositionY[i] = random(coinsSize, height - coinsSize);  
        coinsActive[i] = true;
    }
}


void draw()
{
    background(0, 0, 100);
    
    updateCoins();
    updateAvatar();   
}



void updateAvatar()
{
        // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
}

void updateCoins()
{
    // COINS
    for(int i = 0; i < coinsNum; i++)
    {
        
        if(coinsActive[i] == true)
        {
            
            //Check for a collision of the avatar with a coin
            if(positionX >= coinsPositionX[i] && positionX <= coinsPositionX[i] + coinsSize &&
                positionY >= coinsPositionY[i] && positionY <= coinsPositionY[i] + coinsSize)
            {
                coinsActive[i] = false;
                println("Yummy!");
            }
            else
            {
                fill(40, 100, 100);
                rect(coinsPositionX[i], coinsPositionY[i], coinsSize, coinsSize);
            }
        }
    }
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
// Out:
// <div id="canvas_div_4">
//   <b>Sketch #4:</b><br/>
//   <canvas id="canvas_4"></canvas><br/>
// </div>
// <div id="controls_div_4">
//   <button id="run_button_4" onclick="startSketch('4');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_4" onclick="pauseSketch('4');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_4" onclick="setupSketch('4');">
//     setup()
//   </button>
//   <button id="draw_button_4" onclick="drawSketch('4');">
//     draw()
//   </button>
// </div>
// <b>Sketch #4 state:</b> <span id="state_4">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...
