// %% [markdown]
// ### Einfühfung in die Programmierung - WS18/19 - Lena Gieseke
//
//
//
// ### Exercise 05 - Solutions
//
// -----------------------------------

// %% [markdown]
// # Task 05.01
//
// Add an initCoins() function.

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 16;
float[] coinsPositionX = new float[coinsNum];
float[] coinsPositionY = new float[coinsNum];
boolean[] coinsActive = new boolean[coinsNum];


void setup()
{
    size(250, 250); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 0);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    // 05.01 Re-structuring the code
    initCoins();
}


void draw()
{
    background(0, 0, 0);
    
    updateCoins();
    updateAvatar();   
}



void updateAvatar()
{
        // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
}


void initCoins()
{
    for(int i = 0; i < coinsNum; i++)
    {
        coinsPositionX[i] = random(coinsSize, width - coinsSize);
        coinsPositionY[i] = random(coinsSize, height - coinsSize);  
        coinsActive[i] = true;
    } 
}


void updateCoins()
{
    // COINS
    for(int i = 0; i < coinsNum; i++)
    {
        
        if(coinsActive[i] == true)
        {
            
            //Check for a collision of the avatar with a coin
            if(positionX >= coinsPositionX[i] && positionX <= coinsPositionX[i] + coinsSize &&
                positionY >= coinsPositionY[i] && positionY <= coinsPositionY[i] + coinsSize)
            {
                coinsActive[i] = false;
                println("Yummy!");
            }
            else
            {
                fill(40, 100, 100);
                rect(coinsPositionX[i], coinsPositionY[i], coinsSize, coinsSize);
            }
        }
    }
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}

// %% [markdown]
// # Task 05.02 (2 Points)
//
// Distribute the coins evenly on a grid.
//
// There a several ways to solve this task. One way is to follow example 04.02 from lecture as basis. For a better exercise, first try to come to a solution without reading the hints.
//
// Hints to complete the tasks:
// - As we are drawing reaguarly on a grid now, we don't need to save the coins positions anymore as we did it with the random values. We can just re-compute the positions in each draw call. Hence we do not need the variables coinsPositionX and coinsPositionY anymore - delete thouse variables.
// - We divide the canvas into tiles and draw the coins at the center of each tile (example 04.02 from lecture):
//     - Create the global integer variables tileWidth and tileHeight
//     - In the initCoins() function compute the width of one tile by deviding the canvas width by the number of coins. Do the same for the height of a tile.
//     - In the updateCoins() function iterate through all rows and coluoms and use tileHeight and tileWidth as step size for the loop.

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 16;

boolean[] coinsActive = new boolean[coinsNum];


// 05.02 ADD VARIABLES FOR THE TILE SIZE
int tileWidth;
int tileHeight;


void setup()
{
    size(512, 512); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 0);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    initCoins();
}


void draw()
{
    background(0, 0, 0);
    
    updateCoins();
    updateAvatar();   
}



void updateAvatar()
{
    // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
}


void initCoins()
{
    // 05.02 COMPUTE THE TILE WIDTH AND HEIGHT
    tileWidth = (width - 1) / coinsNum;
    tileHeight = (height - 1) / coinsNum;
    
    for(int i = 0; i < coinsNum; i++)
    {
        // 05.02 REMOVE RANDOM POSITIONS 
        coinsActive[i] = true;
    } 
}


void updateCoins()
{
    // COINS
    
    // 05.02 ADD 2D LOOP FOR PLACING COINS EVENLY
    for (int y = 0; y < height; y += tileHeight) 
    {
        for (int x = 0; x < width; x += tileWidth) 
        {
        
            fill(40, 100, 100);
            ellipse(x, y, coinsSize, coinsSize);
        }
    }
}



// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}

// %% [markdown]
// # Task 05.03 (3 Points)
//
// Now, we need to adjust how we handle the activeCoins array in order to make it work with the 2D grid setup.
//
//
// Filling the array
// - We are now drawing tileWidth * tileHeight number of coins. We only compute the values of tileWidth and tileHeight in the initCoins() function. We can also only then initalize the coinsActive array with a size.
//     - Change the global array intialization from boolean[] coinsActive = new boolean[coinsNum]; to boolean[] coinsActive ;
//     - Give the array a size in initCoints() with adding the line coinsActive = new boolean[tileWidth * tileHeight]; after you computed tileWidth and tileHeight.
//     - Also adjust the loop in the initCoins() functions to fill the whole coinsActive array with true, hence iterate over tileWidth * tileHeigh elements.
//
// **CORRECTION: We are now drawing coinNum * coinNum number of coins. coinNum is defined when we initalize the array, hence we could also already initialize the array with that size when defining it.**
//
// Checking for collision
//
// Equally you need to adjust how to access the correct element in the coinsActive array upon a collision with the avatar.
// - Write a new function called checkCollisionAvatarCoin. The function returns a boolean and takes as intput parameter an integer x variable and integer y variable.
//     - This function should return true, if the avatar's position saved in positionX and positionY is colliding with the coin at the input parameter coordinates x and y. If there is no collision, the function should return false.
// - In updateCoins() when we iterate through all coins with two loops we still need to access the activeCoins array with a 1D index. For this create outside of the loop a new integer variable int coinCounter = 0;. Increase the counter inside the 2D loops by one and use it as index for the activeCoins array.
//     - Inside the 2D loop check whether the checkCollisionAvatarCoin(x,y) for the current coin coordinates returns true or false. If it returns true, set coinsActive[counterCoins] to false. If it returns false, check wether the coin at that position is still active and if so, draw the coin.

// %%
// AVATAR
float positionX;
float positionY;

float speed;

int radius;
int hue = 0;

//COINS
int coinsSize = 15;
int coinsNum = 16;

// 05.03 CHANGE DEFINITION
boolean[] coinsActive;


// 05.02 ADD VARIABLES FOR THE TILE SIZE
int tileWidth;
int tileHeight;


void setup()
{
    size(512, 512); 
    
    colorMode(HSB, 360, 100, 100);
    background(0, 0, 0);
    fill(200, 100, 100);
    noStroke();
    
    positionX = 0.5 * width;
    positionY = 0.5 * height;
    radius = 15;
    speed = 5;
    
    
    initCoins();
}


void draw()
{
    background(0, 0, 0);
    
    updateCoins();
    updateAvatar();   
}



void updateAvatar()
{
    // AVATAR
    hue++;
    if(hue >= 360)
    {
        hue = 0;
    }
    fill(hue, 100, 100);
    ellipse(positionX, positionY, 2*radius, 2*radius);
    
    
}


void initCoins()
{
    // 05.02 COMPUTE THE TILE WIDTH AND HEIGHT
    tileWidth = width / coinsNum;
    tileHeight = height / coinsNum;
    
    // 05.03 GIVING THE ARRAY THE CORRECT SIZE
    coinsActive = new boolean[coinsNum * coinsNum]; 
    
    // 05.03 ITERATING WITH THE CORRECT SIZE
    for(int i = 0; i < coinsNum * coinsNum; i++)
    {
        //REMOVE RANDOM POSITIONS 
        coinsActive[i] = true;
    } 
}


void updateCoins()
{
    // COINS
    
    // 05.03 NEW COIN COUNTER VARIABLE
    int coinCounter = 0;
    
    // 05.02 ADD 2D LOOP FOR PLACING COINS EVENLY
    for (int y = 0; y < height; y += tileHeight) 
    {
        for (int x = 0; x < width; x += tileWidth) 
        {
            
            // 05.03 CHECK FOR COIN-AVATAR COLLISION 
            if(checkCollisionAvatarCoin(x, y))
            {
                coinsActive[coinCounter] = false;
            }
            else
            {
                if(coinsActive[coinCounter])
                {
                    fill(40, 100, 100);
                    ellipse(x + tileWidth *0.5, y + tileHeight *0.5, coinsSize, coinsSize);
                }
            }

            
            // 05.03 INCREASE COIN COUNTER
            coinCounter++;
        }
    }
}

// 05.03 CHECK FOR COLLISION BETWEEN AVATAR AND X and Y
boolean checkCollisionAvatarCoin(int coinX, int coinY)
{
     if(positionX >= coinX - coinsSize && positionX <= coinX + coinsSize &&
                positionY >= coinY - coinsSize && positionY <= coinY + coinsSize)
    { 
        return true;
    }
    else
    {
        return false;
    }
}


// Called if a key was 
// pressed
void keyPressed()
{
    
    if (key == CODED) 
    {
        if (keyCode == UP) 
        {
            if(positionY >= radius)
            {
                positionY -= speed;
            }
        } 
        else if (keyCode == DOWN) 
        {
            if(positionY <= (height - radius))
            {
                positionY += speed;
            }  
        }
        else if (keyCode == LEFT) 
        {
            if(positionX >= radius)
            {
                positionX -= speed;
            } 
            
        } 
        else if (keyCode == RIGHT) 
        {
            if(positionX <= (width - radius))
            {
                positionX += speed;
            } 
            
        } 
    } 
    else 
    {
        // Clearing the screen
        if(key == 'c')
        {
            background(0, 0, 100);
        }
    }
}
